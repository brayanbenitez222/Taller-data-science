# %% [markdown]
# # Tipo de dato string

# %%
Nombre1 = "Cristian"
Nombre2 =  'Santiago'
print(Nombre1)
print(Nombre2)
# Out:
# Cristian
# Santiago

# %%
# concatenacion
print(Nombre1 + " " + Nombre2)
# Out:
# Cristian Santiago

# %%
'Santiago' in globals().get('Nombre1', '')
# Out:
# False

# %%
texto1 = "Hola mundo"
texto1[0]
# Out:
# 'H'

# %%
texto1[0:4]
# Out:
# 'Hola'

# %%
texto1[0:10:2]
# Out:
# 'Hl ud'

# %%
texto1[-1]
# Out:
# 'o'

# %%
type(texto1)
# Out:
# str

# %%
text = ("PeRRo")
print(text.lower())
print(text.upper())
print(text.title())
print(text.capitalize())
# Out:
# perro
# PERRO
# Perro
# Perro

# %%
nombre = "Manuela"
nombre.capitalize()
# Out:
# 'Manuela'

# %%
.find() # buscar un caracter o palabra en una cadena de texto
.replace() # reemplazar un caracter o palabra en una cadena de texto

# %%
mensaje = "Hola como esta juanito, como le ha hido hoy?"
mensaje.replace("juanito", "Diego")
# Out:
# 'Hola como esta Diego, como le ha hido hoy?'

# %%
mensaje.find("juanito") # 10
# Out:
# 15

# %%
tupla1 = (1, 2, 3, 4, 5)
print(tupla1[3])
lista1 = [1, 2, 3, 4, 5]
print(lista1[2])
diccionario = {"nombre": "Santiago", "apellido": "Gonzalez", "edad": 21}
print(diccionario["nombre"])
conjunto1 = {1, 2, 3, 4, 5}
print(conjunto1)
tupla2 = tupla1[0:3]  
print(tupla2)
tupla3 = ((1, 2), (3, 4), (5, 6))
print(tupla3[0][1])
# Out:
# 4
# 3
# Santiago
# {1, 2, 3, 4, 5}
# (1, 2, 3)
# 2

# %%
mi_lista = [1, 2, 3, 4, 5]
mi_lista.append(6)
print(mi_lista)
lista_de_listas = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(lista_de_listas[0][0])
mi_lista = [1, 2, 3, 4, 5]
mi_lista.append(6)
mi_lista.extend([7, 8, 9])
mi_lista.insert(0, 0)
# Out:
# [1, 2, 3, 4, 5, 6]
# 1

# %%
#diccionario 
mi_diccionario = {"nombre": "Abelardo", "apellido": "de la Aspriella", "edad": 30}
print(mi_diccionario["nombre"])
print(mi_diccionario.get("nombre"))
print(list(mi_diccionario.keys()))
print(list(mi_diccionario.values()))
print(list(mi_diccionario.items()))
print(mi_diccionario.pop("edad"))
print(mi_diccionario)
# Out:
# Abelardo
# Abelardo
# ['nombre', 'apellido', 'edad']
# ['Abelardo', 'de la Aspriella', 30]
# [('nombre', 'Abelardo'), ('apellido', 'de la Aspriella'), ('edad', 30)]
# 30
# {'nombre': 'Abelardo', 'apellido': 'de la Aspriella'}

# %%
a = 30
if a < 20:
    print("a es menor que 20")
else:
    print("a no es menor que 20")
# Condicionales anidados
a = 10
if a < 20:
    if a < 10:
        print("a es menor que 10")
    else:
        print("a es mayor o igual que 10")

# ingreso por teclado
a = int(input("Ingrese un numero 1: "))
b = int(input("Ingrese otro numero 2: "))
c = int(input("Ingrese otro numero 3: "))

if a > b and a > c:
    print("a es mayor que b y c")
elif b > a and b > c:
    
    print("b es mayor que a y c")
else:
    print("c es mayor que a y b")
# Out:
# a no es menor que 20
# a es mayor o igual que 10
# c es mayor que a y b

# %%
#comparadores
# ==, !=, >, <, >=, <=
#operadores logicos
# and, or, not
# Realizar un programa que al recibir una califcaion, le deje un mensade de:
# si tuvopor debajo de 3.0 resultado es deficiente
# si obtuvo valor entre 3.0 a 3.5 el resultado es aceptable
# si obtuvo valor entre 3.5 a 4.0 el resultado es bueno
# si obtuvo valor entre 4.0 a 4.5 el resultado es muy bueno
# si obtuvo valor entre 4.5 a 5.0 el resultado es excelente o sobre
nota = float(input("Ingrese su calificacion: "))
if nota < 3.0:
    print("Deficiente")
elif nota >= 3.0 and nota < 3.5:
    print("Aceptable")
elif nota >= 3.5 and nota < 4.0:
    print("Bueno")
elif nota >= 4.0 and nota < 4.5:
    print("Muy bueno")
else:
    print("Excelente")
# Out:
# Bueno

# %%
#bucles
# while, for, break, continue, pass
contraseña = "1234"
clave = input("Ingrese la contraseña: ")
while clave != contraseña:
    print("Contraseña incorrecta")
    clave = input("Ingrese la contraseña: ")
print("Contraseña correcta")
# Out:
# Contraseña incorrecta
# Contraseña incorrecta
# Contraseña correcta

# %%
# for
frutas = ["manzana", "banana", "cereza", "durazno", "kiwi", "mango", "naranja", "pera", "sandia", "uva"]
 
for fruta in frutas:
    print(fruta)
# Out:
# manzana
# banana
# cereza
# durazno
# kiwi
# mango
# naranja
# pera
# sandia
# uva

# %%
for i in range(7):
    print(frutas[i])
# Out:
# manzana
# banana
# cereza
# durazno
# kiwi
# mango
# naranja

# %%
#Recorre un diccionario con un bucle for
mi_diccionario = {"nombre: ": "Santaigo", "apellido: ": "Gonzalez", "edad: ": 21}
for clave, valor in mi_diccionario.items():
    print(clave, valor)

for index, dato in enumerate(frutas):
    print(index, dato)
# Out:
# nombre:  Santaigo
# apellido:  Gonzalez
# edad:  21
# 0 manzana
# 1 banana
# 2 cereza
# 3 durazno
# 4 kiwi
# 5 mango
# 6 naranja
# 7 pera
# 8 sandia
# 9 uva

# %%
i = len(frutas)
print(i)
for index in range(i):
    print(index, frutas[index])
# Out:
# 10
# 0 manzana
# 1 banana
# 2 cereza
# 3 durazno
# 4 kiwi
# 5 mango
# 6 naranja
# 7 pera
# 8 sandia
# 9 uva

# %%
def saludar(nombre):
    print("Hola " + nombre)
saludar("Santaigo")
def sumar(a, b):
    return a + b
sumar(50, 30)
def restar(a, b):
    return a - b
restar(80, 10)
# Out:
# Hola Santaigo
# 70
