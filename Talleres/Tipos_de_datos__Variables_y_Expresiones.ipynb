# %% [markdown]
# ¿Cuál es el tipo de dato del resultado de: 6 / 2?: float

# %%
# tu código
type(6/2)
# Out:
# float

# %% [markdown]
# ¿Qué tipo de resultado tiene la operación: 6 // 2?: int

# %%
# tu código
type(6//2)
# Out:
# int

# %% [markdown]
# ¿Cuál es el tipo de resultado de: "Hola, mundo!"?:str

# %%
# tu código
type("Hola mundo!")
# Out:
# str

# %% [markdown]
# Escribe el código para convertir el siguiente número que representa el ID de empleado "1001" a un número entero.

# %%
# tu código
Id_empleado = "1001"
int(Id_empleado)
# Out:
# 1001

# %% [markdown]
# Escribe el código para convertir este número que representa el valor financiero "1234.56" a un número de punto flotante.

# %%
# tu código
ValorFinanciero = 1234.56
float(ValorFinanciero)
# Out:
# 1234.56

# %% [markdown]
# Escribe el código para convertir este número de teléfono 123-456-7890 a una cadena de texto.

# %%
# tu código
numero = 1234567890
numero_str = str(numero)
print(numero_str[0:3]+"-"+numero_str[3:6]+"-"+numero_str[6:10])
type(numero_str)
# Out:
# 123-456-7890
# str

# %% [markdown]
# Escribe una expresión para sumar 30 y 20 y restar 40.

# %%
# tu código
resul = 30 + 20 - 40

print(resul)
# Out:
# 10

# %% [markdown]
# Escribe una expresión para restar 5 de 55 y dividir el resultado entre 10.

# %%
# tu código
resul = (55-5)/10
print (int(resul))
# Out:
# 5

# %% [markdown]
# Escribe una expresión para multiplicar 6 por 10 y dividir el resultado entre 12.

# %%
# tu código
resul = (6*10)/12
print(int(resul))
# Out:
# 5

# %% [markdown]
# ¿Cuál es el valor de x donde x = 3 + 2 * 2?: 7

# %%
# tu código
x = 3 + 2 * 2
print (int(x))
# Out:
# 7

# %% [markdown]
# ¿Cuál es el valor de y donde y = (3 + 2) * 2?: 10

# %%
# tu código

y = (3 + 2) * 2
print (int(y))
# Out:
# 10

# %% [markdown]
# ¿Cuál es el valor de z donde z = x + y?: 17

# %%
# tu código
z = x + y
print(int(z))
# Out:
# 17
